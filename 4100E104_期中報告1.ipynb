# %% [markdown]
# <a href="https://colab.research.google.com/github/yukai920722/2022-ksu-11002/blob/main/4100E104_%E6%9C%9F%E4%B8%AD%E5%A0%B1%E5%91%8A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas資料匯入
#
# <P>1.讀寫CSV檔案</p>
# <P>2.讀寫EXCEL檔案 Reading and writing data in Excel format</p>
# <P>3.讀寫 JSON 檔案</p>
# <P>4.讀取網頁表格資料</p>

# %% [markdown]
# # 1.讀寫CSV檔案
# <P>先下載遠端資料到Google Colab</p>

# %%
# !wget https://raw.githubusercontent.com/PacktPublishing/Learning-Pandas-Second-Edition/master/data/msft.csv
# Out:
# --2022-04-13 02:13:47--  https://raw.githubusercontent.com/PacktPublishing/Learning-Pandas-Second-Edition/master/data/msft.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153109 (150K) [text/plain]
# Saving to: ‘msft.csv’
#
# msft.csv            100%[===================>] 149.52K  --.-KB/s    in 0.02s
#
# 2022-04-13 02:13:47 (6.73 MB/s) - ‘msft.csv’ saved [153109/153109]

# %%
ls
# Out:
# msft.csv  sample_data/

# %% [markdown]
# #### 檢視前十筆資料

# %%
# !head -n10 msft.csv
# Out:
# Date,Open,High,Low,Close,Volume
# 7/21/2014,83.46,83.53,81.81,81.93,2359300
# 7/18/2014,83.3,83.4,82.52,83.35,4020800
# 7/17/2014,84.35,84.63,83.33,83.63,1974000
# 7/16/2014,83.77,84.91,83.66,84.91,1755600
# 7/15/2014,84.3,84.38,83.2,83.58,1874700
# 7/14/2014,83.66,84.64,83.11,84.4,1432100
# 7/11/2014,83.55,83.98,82.85,83.35,2001400
# 7/10/2014,85.2,85.57,83.36,83.42,2713300
# 7/9/2014,84.83,85.79,84.76,85.5,1540700

# %% [markdown]
# #2.讀寫excel檔案 Reading and writing data in Excel format
# <p>下載excel檔案</P>
#
# <P>再upload到Google Colab</P>

# %%
# !wget https://github.com/PacktPublishing/Learning-Pandas-Second-Edition/blob/master/data/stocks.xlsx
# Out:
# --2022-04-13 02:42:26--  https://github.com/PacktPublishing/Learning-Pandas-Second-Edition/blob/master/data/stocks.xlsx
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘stocks.xlsx’
#
# stocks.xlsx             [ <=>                ] 126.33K  --.-KB/s    in 0.08s
#
# 2022-04-13 02:42:27 (1.64 MB/s) - ‘stocks.xlsx’ saved [129366]

# %%
ls
# Out:
# msft.csv  sample_data/  stocks.xlsx

# %%
df = pd.read_excel("./stocks.xlsx")
df[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-6edd81e0d1eb> in <module>()
# ----> 1 df = pd.read_excel("./stocks.xlsx")
#       2 df[:5]
#
# NameError: name 'pd' is not defined

# %% [markdown]
# #3.寫 JSON 檔案

# %%
{
     "firstName": "John",
     "lastName": "Smith",
     "sex": "male",
     "age": 25,
     "address": 
     {
         "streetAddress": "21 2nd Street",
         "city": "New York",
         "state": "NY",
         "postalCode": "10021"
     },
     "phoneNumber": 
     [
         {
           "type": "home",
           "number": "212 555-1234"
         },
         {
           "type": "fax",
           "number": "646 555-4567"
         }
     ]
 }
# Out:
# {'address': {'city': 'New York',
#   'postalCode': '10021',
#   'state': 'NY',
#   'streetAddress': '21 2nd Street'},
#  'age': 25,
#  'firstName': 'John',
#  'lastName': 'Smith',
#  'phoneNumber': [{'number': '212 555-1234', 'type': 'home'},
#   {'number': '646 555-4567', 'type': 'fax'}],
#  'sex': 'male'}

# %% [markdown]
# #4.讀取網頁表格資料

# %%
import pandas as pd

bus_table = pd.read_html("https://www.ubus.com.tw/Booking/FareInquiry")
print(bus_table)
# 44    【1661】礁溪轉運站-桃園機場         200元  200元  100元                NaN
# 45    【1661】宜蘭轉運站-桃園機場         250元  250元  125元                NaN
# 46    【1661】羅東轉運站-桃園機場         280元  280元  140元                NaN
# 47         【9019】朝馬-溪湖          90元   90元   45元                NaN
# 48         【9019】朝馬-二林         110元  110元   55元                NaN
# 49         【9019】朝馬-大城         140元  140元   70元                NaN
# 50         【9019】朝馬-麥寮         190元  190元   95元                NaN
# 51     【1662】桃園車站－松山機場          74元   74元   37元                NaN
# 52   【1662】中正藝文特區-松山機場          58元   58元   29元                NaN
# 53    【1662】經國轉運站-松山機場          51元   51元   26元                NaN
# 54         【1650】高雄－北港         220元  220元  110元                NaN
# 55         【1651】高雄－北港         220元  220元  110元                NaN
# 56         【1651】高雄－麻豆         115元  115元   55元                NaN
# 57         【1660】板橋－高雄         490元  500元  250元                NaN
#
#
#    Unnamed: 5_level_1
#    Unnamed: 5_level_2
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN
# 50                NaN
# 51                NaN
# 52                NaN
# 53                NaN
# 54                NaN
# 55                NaN
# 56                NaN
# 57                NaN  ,            短區間販售票價表                                              \
#    ※下列短區間請至各自營站現場購買
#                路線名稱 全票 / 優惠全票 票價        半票票價 Unnamed: 4_level_2
#                路線名稱         優惠時段  原價時段  半票票價 Unnamed: 4_level_3
# 0           台北 - 南崁          40元   40元   20元                NaN
# 1         台北 - 中壢新屋          75元   75元   35元                NaN
# 2           台北 - 竹科         110元  110元   50元                NaN
# 3        台北 - 中港轉運站         230元  240元  120元                NaN
# 4        市府轉運站 - 三峽          60元   60元   30元                NaN
# 5           竹科 - 台中         120元  120元   65元                NaN
# 6        中港轉運站 - 板橋         220元  235元  115元                NaN
# 7        中港轉運站 - 鹿港          70元   70元   35元                NaN
# 8        中港轉運站 - 員林          55元   55元   25元                NaN
# 9        中港轉運站 - 溪湖          55元   55元   25元                NaN
# 10       中港轉運站 - 二林         100元  100元   50元                NaN
# 11       中港轉運站 - 西港         140元  140元   70元                NaN
# 12       中港轉運站 - 草屯          65元   65元   30元                NaN
# 13       中港轉運站 - 竹山         150元  150元   75元                NaN
# 14       中港轉運站 - 西螺          75元   75元   35元                NaN
# 15       中港轉運站 - 虎尾         110元  110元   55元                NaN
# 16   中港轉運站 - 北港土庫元長         180元  180元   90元                NaN
# 17   中港轉運站 - 水林下崙口湖         180元  180元   90元                NaN
# 18       中港轉運站 - 台西         180元  180元   90元                NaN
# 19      中港轉運站 - 三條崙         180元  180元   90元                NaN
# 20       中港轉運站 - 嘉義         145元  145元   70元                NaN
# 21       中港轉運站 - 布袋         210元  210元  100元                NaN
# 22       中港轉運站 - 台南         200元  230元  110元                NaN
# 23     中港轉運站 - 佳里漚汪         200元  230元  100元                NaN
# 24       中港轉運站 - 高雄         260元  290元  140元                NaN
# 25       中港轉運站 - 屏東         320元  325元  160元                NaN
# 26         北港路 - 麻豆          60元   60元   30元                NaN
# 27         北港路 - 台南         100元  100元   50元                NaN
# 28          新營 - 台南          65元   65元   30元                NaN
# 29        新營 - 佳里漚汪          65元   65元   30元                NaN
# 30          麻豆 - 台南          45元   45元   20元                NaN
# 31          仁德 - 屏東         100元  100元   55元                NaN
# 32          岡山 - 高雄          25元   25元   10元                NaN
# 33          楠梓 - 高雄          25元   25元   10元                NaN
# 34       桃園車站-高速公路局          49元   49元   24元                NaN
# 35   中正藝文特區 - 高速公路局          32元   32元   16元                NaN
# 36    經國轉運站 - 高速公路局          24元   24元   12元                NaN
# 37       松山機場-高速公路局          26元   26元   13元                NaN
# 38       板橋 - 中港轉運站         220元  235元  115元                NaN
# 39       中和 - 中港轉運站         210元  220元  110元                NaN
# 40       中港轉運站 - 中和         210元  220元  110元                NaN
# 41       中港轉運站 - 三峽         220元  220元  110元                NaN
# 42       三峽 - 中港轉運站         220元  220元  110元                NaN
#
#
#
#    Unnamed: 5_level_2
#    Unnamed: 5_level_3
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN  ,           轉乘桃園機場票價表
#    ※下列短區間請至各自營站現場購買
#                  區間            全票            半票
# 0        桃園機場 - 三條崙  395+45=440 元  190+20=210 元
# 1         桃園機場 - 台北   70+45=115 元    35+20=55 元
# 2         桃園機場 - 台南  405+45=450 元  190+20=210 元
# 3      桃園機場 - 員林.西港  275+45=320 元  130+20=150 元
# 4         桃園機場 - 嘉義  375+45=420 元  180+20=200 元
# 5         桃園機場 - 屏東  545+45=590 元  260+20=280 元
# 6         桃園機場 - 彰化  265+45=310 元  120+20=140 元
# 7      桃園機場 - 竹山.南投  275+45=320 元  130+20=150 元
# 8      桃園機場 - 西螺.虎尾  335+45=380 元  160+20=180 元
# 9      桃園機場 - 豐原.東勢  215+45=260 元  110+20=130 元
# 10        桃園機場 - 高雄  515+45=560 元  250+20=270 元]

# %% [markdown]
# #使用pandas.Series() 建立Series

# %%
obj = pd.Series([41, 27, -25, 13,21])
obj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8ca120b8504c> in <module>()
# ----> 1 obj = pd.Series([41, 27, -25, 13,21])
#       2 obj
#
# NameError: name 'pd' is not defined

# %%
obj.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bab89682be14> in <module>()
# ----> 1 obj.values
#
# NameError: name 'obj' is not defined

# %%
obj.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-75bf3bfc1818> in <module>()
# ----> 1 obj.index
#
# NameError: name 'obj' is not defined

# %% [markdown]
# #設定IPython筆記本

# %%
# Commented out IPython magic to ensure Python compatibility.
# import numpy and pandas
import numpy as np
import pandas as pd

# used for dates
import datetime
from datetime import datetime, date

# Set formattign options
pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 7)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', 60)

# bring in matplotlib for graphics
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 要先更新版本

# %%
# !pip install --upgrade pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 8.1 MB/s
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (4.2.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (3.0.4)
# Installing collected packages: pandas-datareader
#   Attempting uninstall: pandas-datareader
#     Found existing installation: pandas-datareader 0.9.0
#     Uninstalling pandas-datareader-0.9.0:
#       Successfully uninstalled pandas-datareader-0.9.0
# Successfully installed pandas-datareader-0.10.0

# %% [markdown]
# #從Google取得與組織股票資料

# %%
# import data reader package
import pandas_datareader as pdr

# read data from Yahoo! Finance for a specific 
# stock specified by ticker and between the start and end dates
def get_stock_data(ticker, start, end):
    # read the data
    data = pdr.data.DataReader(ticker, 'yahoo', start, end)

    # rename this column
    data.insert(0, "Ticker", ticker)
    return data

# request the three years of data for MSFT
start = datetime(2012, 1, 1)
end = datetime(2014, 12, 31)
get_stock_data("MSFT", start, end)[:5]

# gets data for multiple stocks
# tickers: a list of stock symbols to fetch
# start and end are the start end end dates
def get_data_for_multiple_stocks(tickers, start, end):
    # we return a dictionary
    stocks = dict()
    # loop through all the tickers
    for ticker in tickers:
        # get the data for the specific ticker
        s = get_stock_data(ticker, start, end)
        # add it to the dictionary
        stocks[ticker] = s
    # return the dictionary
    return stocks

# get the data for all the stocks that we want
raw = get_data_for_multiple_stocks(
    ["MSFT", "AAPL", "GE", "IBM", "AA", "DAL", "UAL", "PEP", "KO"],
    start, end)

# take a peek at the data for MSFT
raw['MSFT'][:5]
# Out:
#            Ticker       High        Low       Open  \
# Date
# 2012-01-03   MSFT  26.959999  26.389999  26.549999
# 2012-01-04   MSFT  27.469999  26.780001  26.820000
# 2012-01-05   MSFT  27.730000  27.290001  27.379999
# 2012-01-06   MSFT  28.190001  27.530001  27.530001
# 2012-01-09   MSFT  28.100000  27.719999  28.049999
#
#                 Close      Volume  Adj Close
# Date
# 2012-01-03  26.770000  64731500.0  21.623131
# 2012-01-04  27.400000  80516100.0  22.132013
# 2012-01-05  27.680000  56081400.0  22.358173
# 2012-01-06  28.110001  99455500.0  22.705503
# 2012-01-09  27.740000  59706800.0  22.406641

# %% [markdown]
# #繪製股價時間序列的圖

# %%
# given the dictionary of data frames,
# pivots a given column into values with column
# names being the stock symbols
def pivot_tickers_to_columns(raw, column):
    items = []
    # loop through all dictionary keys
    for key in raw:
        # get the data for the key
        data = raw[key]
        # extract just the column specified
        subset = data[["Ticker", column]]
        # add to items
        items.append(subset)
    
    # concatenate all the items
    combined = pd.concat(items)
    # reset the index
    ri = combined.reset_index()
    # return the pivot
    return ri.pivot("Date", "Ticker", column)

# do the pivot
close_px = pivot_tickers_to_columns(raw, "Close")
# peek at the result
close_px[:5]
# Out:
# Ticker             AA       AAPL   DAL  ...       MSFT  \
# Date                                    ...
# 2012-01-03  22.179689  14.686786  8.04  ...  26.770000
# 2012-01-04  22.708349  14.765714  8.01  ...  27.400000
# 2012-01-05  22.492081  14.929643  8.33  ...  27.680000
# 2012-01-06  22.011480  15.085714  8.32  ...  28.110001
# 2012-01-09  22.660290  15.061786  8.28  ...  27.740000
#
# Ticker            PEP        UAL
# Date
# 2012-01-03  66.400002  18.900000
# 2012-01-04  66.739998  18.520000
# 2012-01-05  66.220001  18.389999
# 2012-01-06  65.389999  18.209999
# 2012-01-09  65.730003  17.930000
#
# [5 rows x 9 columns]

# %% [markdown]
# #Plotting time-series prices

# %%
# plot the closing prices of AAPL
close_px['AAPL'].plot();

# plot the closing prices of MSFT
close_px['MSFT'].plot();

# plot MSFT vs AAPL on the same chart
close_px[['MSFT', 'AAPL']].plot();

# %% [markdown]
# # Plotting volume series data

# %%
# pivot the volume data into columns
volumes = pivot_tickers_to_columns(raw, "Volume")
volumes.tail()

# plot the volume for MSFT
msft_volume = volumes[["MSFT"]]
plt.bar(msft_volume.index, msft_volume["MSFT"])
plt.gcf().set_size_inches(15,8)

# draw the price history on the top
top = plt.subplot2grid((4,4), (0, 0), rowspan=3, colspan=4)
top.plot(close_px['MSFT'].index, close_px['MSFT'], 
         label='MSFT Close')
plt.title('MSFT Close Price 2012 - 2014')
plt.legend(loc=2)

# and the volume along the bottom
bottom = plt.subplot2grid((4,4), (3,0), rowspan=1, colspan=4)
bottom.bar(msft_volume.index, msft_volume['MSFT'])
plt.title('Microsoft Trading Volume 2012 - 2014')
plt.subplots_adjust(hspace=0.75)
plt.gcf().set_size_inches(15,8)

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# calculate daily percentage change
daily_pc = close_px / close_px.shift(1) - 1
daily_pc[:5]

# check the percentage on 2012-01-05
close_px.loc['2012-01-05']['AAPL'] / \
    close_px.loc['2012-01-04']['AAPL'] -1

# plot daily percentage change for AAPL
daily_pc["AAPL"].plot();

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# calculate daily cumulative return
daily_cr = (1 + daily_pc).cumprod()
daily_cr[:5]

# plot all the cumulative returns to get an idea 
# of the relative performance of all the stocks
daily_cr.plot(figsize=(8,6))
plt.legend(loc=2);

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# resample to end of month and forward fill values
monthly = close_px.asfreq('M').ffill()
monthly[:5]

# calculate the monthly percentage changes
monthly_pc = monthly / monthly.shift(1) - 1
monthly_pc[:5]

# calculate monthly cumulative return
monthly_cr = (1 + monthly_pc).cumprod()
monthly_cr[:5]

# plot the monthly cumulative returns
monthly_cr.plot(figsize=(12,6))
plt.legend(loc=2);

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# histogram of the daily percentage change for AAPL
aapl = daily_pc['AAPL']
aapl.hist(bins=50);

# matrix of all stocks daily % changes histograms
daily_pc.hist(bins=50, figsize=(8,6));

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# extract just MSFT close
msft_close = close_px[['MSFT']]['MSFT']
# calculate the 30 and 90 day rolling means
ma_30 = msft_close.rolling(window=30).mean()
ma_90 = msft_close.rolling(window=90).mean()
# compose into a DataFrame that can be plotted
result = pd.DataFrame({'Close': msft_close, 
                       '30_MA_Close': ma_30,
                       '90_MA_Close': ma_90})
# plot all the series against each other
result.plot(title="MSFT Close Price")
plt.gcf().set_size_inches(12,8)

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# plot the daily percentage change of MSFT vs AAPL
plt.scatter(daily_pc['MSFT'], daily_pc['AAPL'])
plt.xlabel('MSFT')
plt.ylabel('AAPL');

# demonstrate perfect correlation
plt.scatter(daily_pc['MSFT'], daily_pc['MSFT']);

from pandas.plotting import scatter_matrix
# plot the scatter of daily price changed for ALL stocks
scatter_matrix(daily_pc, diagonal='kde', figsize=(12,12));

# %% [markdown]
# # Calculating simple daily percentage change
# *斜體文字*

# %%
# calculate the correlation between all the stocks relative
# to daily percentage change
corrs = daily_pc.corr()
corrs

# plot a heatmap of the correlations
plt.imshow(corrs, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corrs)), corrs.columns)
plt.yticks(range(len(corrs)), corrs.columns)
plt.gcf().set_size_inches(8,8)

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# 75 period minimum
min_periods = 75
# calculate the volatility
vol = daily_pc.rolling(window=min_periods).std() * \
        np.sqrt(min_periods)
# plot it
vol.plot(figsize=(10, 8));

# %% [markdown]
# # Calculating simple daily percentage change

# %%
# generate a scatter of the mean vs std of daily % change
plt.scatter(daily_pc.mean(), daily_pc.std())
plt.xlabel('Expected returns')
plt.ylabel('Risk')

# this adds fancy labels to each dot, with an arrow too
for label, x, y in zip(daily_pc.columns, 
                       daily_pc.mean(), 
                       daily_pc.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (30, -30),
        textcoords = 'offset points', ha = 'right', 
        va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', 
                    fc = 'yellow', 
                    alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', 
                          connectionstyle = 'arc3,rad=0'))

# set ranges and scales for good presentation
plt.xlim(-0.001, 0.003)
plt.ylim(0.005, 0.0275)

# set size
plt.gcf().set_size_inches(8,8)
